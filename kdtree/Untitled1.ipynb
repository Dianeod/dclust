# %%
plt:.p.import[`matplotlib]`:pyplot
cf:.p.import[`scipy.optimize;`:curve_fit;<]

# %%
func:{[x;a;b;c]a+b*exp(0.02*(x-c))}

xval:-200 -150 -100 -50 0f
yval:642.5 642.5 642.5 642.6 643.0f

show ans:first cf[func;xval;yval;1 1 1f]
# Out:
# 642.4549 107.1303 265.8721

# %%
fitted:func[;ans[0];ans[1];ans[2]]each xval

# %%
/plt[`:figure][`figure pykw [6;4]]
plt[`:scatter][xval;yval;`label pykw `data];
plt[`:plot][xval;fitted;`label pykw func];
plt[`:legend][`loc pykw `best];
plt[`:show][]
# Out:
# {[f;x]embedPy[f;x]}[foreign]enlist

# %%
# Out:
# {[x;a;b;c]a+b*exp(0.02*(x-c))}
